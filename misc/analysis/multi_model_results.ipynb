# %% [markdown]
# This notebook is used to analyze the results of the multi-model experiments.

# %%
import sys
sys.path.append("../")

from pathlib import Path
import json
from src.ensembles import MODEL_GROUPS
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


RESULTS_DIR = Path("../smoothie_data/multi_model_results")

# %%
def plot_exp(exp_dir: Path, metric: str):
    scores = []
    for model_group in MODEL_GROUPS:
        scores_fpath = exp_dir / model_group / "scores.json"
        scores.append(json.loads(scores_fpath.read_text())[metric])
    
    keys = ["pick_random"]
    
    data = []
    for key in keys:
        for model_group, score_dict in zip(MODEL_GROUPS, scores):
            data.append({"Method": key, "Score": score_dict[key], "Model Group": model_group, "Metric": metric})

    df = pd.DataFrame(data)
    
    plt.figure(figsize=(12, 6))
    ax = sns.barplot(x="Method", y="Score", data=df, capsize=0.1, errorbar="sd")
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
    plt.title("Performance Comparison of Different Methods")
    plt.tight_layout()
    plt.show()

    return df

# %%
plot_exp(RESULTS_DIR / "squad", metric="squad_acc")
# Out:
# /var/folders/p0/5fzn9rtx1ps841s4_3tw4t440000gn/T/ipykernel_98554/356975414.py:18: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha='right')
#          Method   Score  Model Group     Metric
# 0   pick_random  0.5944   ensemble_1  squad_acc
# 1   pick_random  0.6926   ensemble_2  squad_acc
# 2   pick_random  0.5670   ensemble_3  squad_acc
# 3   pick_random  0.6608   ensemble_4  squad_acc
# 4   pick_random  0.6588   ensemble_5  squad_acc
# 5   pick_random  0.6404   ensemble_6  squad_acc
# 6   pick_random  0.6830   ensemble_7  squad_acc
# 7   pick_random  0.6756   ensemble_8  squad_acc
# 8   pick_random  0.6844   ensemble_9  squad_acc
# 9   pick_random  0.6046  ensemble_10  squad_acc
# 10  pick_random  0.6180  ensemble_11  squad_acc
# 11  pick_random  0.6477  ensemble_12  squad_acc
# 12  pick_random  0.6356  ensemble_13  squad_acc
# 13  pick_random  0.6584  ensemble_14  squad_acc
# 14  pick_random  0.6536  ensemble_15  squad_acc
# 15  pick_random  0.6360  ensemble_16  squad_acc
# 16  pick_random  0.6203  ensemble_17  squad_acc
# 17  pick_random  0.6847  ensemble_18  squad_acc
# 18  pick_random  0.6765  ensemble_19  squad_acc
# 19  pick_random  0.6675  ensemble_20  squad_acc
# 20  pick_random  0.6005  ensemble_21  squad_acc
# 21  pick_random  0.6120  ensemble_22  squad_acc
# 22  pick_random  0.5956  ensemble_23  squad_acc
# 23  pick_random  0.6541  ensemble_24  squad_acc
# 24  pick_random  0.6716  ensemble_25  squad_acc
# 25  pick_random  0.6381  ensemble_26  squad_acc
# 26  pick_random  0.6190  ensemble_27  squad_acc
# 27  pick_random  0.6594  ensemble_28  squad_acc
# 28  pick_random  0.6294  ensemble_29  squad_acc
# 29  pick_random  0.6360  ensemble_30  squad_acc
# 30  pick_random  0.6115  ensemble_31  squad_acc
# 31  pick_random  0.6797  ensemble_32  squad_acc
# 32  pick_random  0.6291  ensemble_33  squad_acc
# 33  pick_random  0.5960  ensemble_34  squad_acc
# 34  pick_random  0.6563  ensemble_35  squad_acc
# 35  pick_random  0.6855  ensemble_36  squad_acc
# 36  pick_random  0.6437  ensemble_37  squad_acc
# 37  pick_random  0.6255  ensemble_38  squad_acc
# 38  pick_random  0.6239  ensemble_39  squad_acc
# 39  pick_random  0.6234  ensemble_40  squad_acc
# 40  pick_random  0.6250  ensemble_41  squad_acc
# 41  pick_random  0.6425  ensemble_42  squad_acc
# 42  pick_random  0.6774  ensemble_43  squad_acc
# 43  pick_random  0.6563  ensemble_44  squad_acc
# 44  pick_random  0.6284  ensemble_45  squad_acc
# 45  pick_random  0.6233  ensemble_46  squad_acc
# 46  pick_random  0.6375  ensemble_47  squad_acc
# 47  pick_random  0.6356  ensemble_48  squad_acc
# 48  pick_random  0.6545  ensemble_49  squad_acc
# 49  pick_random  0.6418  ensemble_50  squad_acc
